# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("odev_tenis.csv")

# %%
df.head()
# Out:
#     outlook  temperature  humidity  windy play
# 0     sunny           85        85  False   no
# 1     sunny           80        90   True   no
# 2  overcast           83        86  False  yes
# 3     rainy           70        96  False  yes
# 4     rainy           68        80  False  yes

# %%
df.windy = df.windy.astype("str")

# %%
df.windy.replace({"True":1, "False":0},inplace=True)

# %%
df.dtypes
# Out:
# outlook        object
# temperature     int64
# humidity        int64
# windy           int64
# play           object
# dtype: object

# %%
df.head()
# Out:
#     outlook  temperature  humidity  windy play
# 0     sunny           85        85      0   no
# 1     sunny           80        90      1   no
# 2  overcast           83        86      0  yes
# 3     rainy           70        96      0  yes
# 4     rainy           68        80      0  yes

# %%
df.play.replace({"yes":1, "no":0},inplace=True)

# %%
from sklearn import preprocessing

# %%
cn = df["outlook"].to_frame()
ohe = preprocessing.OneHotEncoder()

# %%
res = ohe.fit_transform(cn).toarray()

# %%
res = pd.DataFrame(res)

# %%
df.drop("outlook",axis=1,inplace=True)
df_s = pd.concat([df,res],axis=1)

# %%
df_s
# Out:
#     temperature  humidity  windy  play    0    1    2
# 0            85        85      0     0  0.0  0.0  1.0
# 1            80        90      1     0  0.0  0.0  1.0
# 2            83        86      0     1  1.0  0.0  0.0
# 3            70        96      0     1  0.0  1.0  0.0
# 4            68        80      0     1  0.0  1.0  0.0
# 5            65        70      1     0  0.0  1.0  0.0
# 6            64        65      1     1  1.0  0.0  0.0
# 7            72        95      0     0  0.0  0.0  1.0
# 8            69        70      0     1  0.0  0.0  1.0
# 9            75        80      0     1  0.0  1.0  0.0
# 10           75        70      1     1  0.0  0.0  1.0
# 11           72        90      1     1  1.0  0.0  0.0
# 12           81        75      0     1  1.0  0.0  0.0
# 13           71        91      1     0  0.0  1.0  0.0

# %%
x = df_s.drop("play",axis=1)
y = df[["play"]]

# %%
x
# Out:
#     temperature  humidity  windy    0    1    2
# 0            85        85      0  0.0  0.0  1.0
# 1            80        90      1  0.0  0.0  1.0
# 2            83        86      0  1.0  0.0  0.0
# 3            70        96      0  0.0  1.0  0.0
# 4            68        80      0  0.0  1.0  0.0
# 5            65        70      1  0.0  1.0  0.0
# 6            64        65      1  1.0  0.0  0.0
# 7            72        95      0  0.0  0.0  1.0
# 8            69        70      0  0.0  0.0  1.0
# 9            75        80      0  0.0  1.0  0.0
# 10           75        70      1  0.0  0.0  1.0
# 11           72        90      1  1.0  0.0  0.0
# 12           81        75      0  1.0  0.0  0.0
# 13           71        91      1  0.0  1.0  0.0

# %%
y
# Out:
#     play
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
# 6      1
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     1
# 13     0

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
sonuc  = lr.predict(x_test)

# %%
sonuc
# Out:
# array([[1.36590871],
#        [0.07803047],
#        [0.8823093 ],
#        [1.47428919],
#        [1.02327232]])

# %%
y_test
# Out:
#     play
# 9      1
# 11     1
# 0      0
# 12     1
# 5      0

# %%
import statsmodels.api as sm

# %%
ones = np.ones((14,1))

# %%
df_s["b"] = ones

# %%
df_s.head()
# Out:
#    temperature  humidity  windy  play    0    1    2    b
# 0           85        85      0     0  0.0  0.0  1.0  1.0
# 1           80        90      1     0  0.0  0.0  1.0  1.0
# 2           83        86      0     1  1.0  0.0  0.0  1.0
# 3           70        96      0     1  0.0  1.0  0.0  1.0
# 4           68        80      0     1  0.0  1.0  0.0  1.0

# %%
x_list = df_s.iloc[:,:7].values

# %%
x_list = x_list.astype("float")

# %%
type(x_list)
# Out:
# numpy.ndarray

# %%
x_list.dtype
# Out:
# dtype('float64')

# %%
model = sm.OLS(y,x_list)
sonuc = model.fit()

# %%
sonuc.summary()
# Out:
# C:\Users\Umut\anaconda3\lib\site-packages\scipy\stats\stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   play   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 5.969e+26
# Date:                Mon, 28 Sep 2020   Prob (F-statistic):           4.08e-93
# Time:                        00:20:59   Log-Likelihood:                 420.93
# No. Observations:                  14   AIC:                            -827.9
# Df Residuals:                       7   BIC:                            -823.4
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
